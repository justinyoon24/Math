# %%
# 2

from sympy import Symbol, solveset, lambdify, Interval, oo  # oo is sympys representation of Infinity
from sympy.plotting import plot
from math import floor

x = Symbol('x')  # Set a symbol
P = 2*x**3 + 18*x**2 + 30*x +9   # Equation for rents
P_fun = lambdify(x, P)
der_P = P.diff(x)  # derivitive of F

dRoots = solveset(der_P, x, Interval(-5, 5)) # Find the roots of our derivitive where x is between -5 and 5
y_vals = [P_fun(r) for r in dRoots]
print(f"Extreme values are {dRoots} at y values of {y_vals} respectively") # gives a set with a single extrema, this is our answer
# Out:
# Extreme values are FiniteSet(-5, -1) at y values of [59, -5] respectively

# %%
# 5
import sympy

x = sympy.Symbol('x')
f = 8 * sympy.sqrt(x) + 2
f_prime = f.diff(x)
f_prime = f_prime - 1.7220
f_fun2 = lambdify(x,f_prime)
dRoots = solveset(f_prime, x)
print(dRoots)
f_fun = lambdify(x,f)
y = (f_fun(7)-f_fun(4))/3
print(y)
sympy.plotting.plot(f_prime)
# Out:
# FiniteSet(5.39577322104729)
# 1.722003496172242

# %%
# 7
from sympy import Symbol, lambdify, plotting

x = Symbol('x')
g = 8 * x **3 - 96 * x**2 + 360 * x
g_first = g.diff(x)
g_second = g_first.diff(x)

print(f"First derivitive is {g_first}")
print(f"Second derivitive is {g_second}")

g_first_f = lambdify(x, g_first)
g_second_f = lambdify(x, g_second)

p1 = g_second_f(3)

print(f"g''(3) = {p1}")

gp = plotting.plot(g, show=False, ylim=(-1000, 1000), line_color='b', label='g', legend=True)
gp1 = plotting.plot(g_first, show=False, line_color='r', label="g'")
gp2 = plotting.plot(g_second, show=False, line_color='g', label="g''")

gp.append(gp1[0])
gp.append(gp2[0])
gp.show()

print("We can visually verify our interpretation of concave down and a maxima")
# Out:
# First derivitive is 24*x**2 - 192*x + 360
# Second derivitive is 48*x - 192
# g''(3) = -48
# We can visually verify our interpretation of concave down and a maxima

# %%
# 14
from sympy import Symbol, lambdify, solve, plotting, oo

t = Symbol('t')
S = (150 * t) / (t + 2)**2

S_prime = S.diff(t)

print("Sales Plot")
plotting.plot(S, xlim=(0, 15), ylim=(0, 100))


dRoots = solveset(S_prime, t, Interval(0, oo)) # Find the roots of our derivitive where x is between 0 and infinity
print(f"Extreme values are {dRoots}") # gives a set with a single extrema, this is our answer

S_func = lambdify(t, S)  # Turn the symbolic equation into a callable function so we can find the S(t) for our found t value
max_val = S_func(dRoots.args[0])
print(f"Maximum profit is {max_val * 1000} and occurs at {dRoots.args[0]}")
# Out:
# Sales Plot
# Extreme values are FiniteSet(2)
# Maximum profit is 18750 and occurs at 2

# %%
x = -6
y = -4*x**2 -24*x +5
print(y)
# Out:
# 5

# %%
# 2

from sympy import Symbol, solveset, lambdify, Interval, oo  # oo is sympys representation of Infinity
from sympy.plotting import plot
from math import floor

x = Symbol('x')  # Set a symbol
P = -4*x**2 - 24*x + 5   # Equation for rents
P_fun = lambdify(x, P)
der_P = P.diff(x)  # derivitive of F

dRoots = solveset(der_P, x, Interval(-6, 0)) # Find the roots of our derivitive where x is between -5 and 5
y_vals = [P_fun(r) for r in dRoots]
print(f"Extreme values are {dRoots} at y values of {y_vals} respectively") # gives a set with a single extrema, this is our answer
# Out:
# Extreme values are FiniteSet(-3) at y values of [41] respectively

# %%
# 5
import sympy

x = sympy.Symbol('x')
f = 3*x**3 - 4*x
f_fun = lambdify(x,f)
y = (f_fun(4)-f_fun(2))/(4-2)
print(y)
f_prime = f.diff(x)
f_prime = f_prime - 80
dRoots = solveset(f_prime, x)
print(dRoots)
# Out:
# 80.0
# FiniteSet(-2*sqrt(21)/3, 2*sqrt(21)/3)

# %%
# 5
import sympy

x = sympy.Symbol('x')
f = 4*(x-4)**(2/3)
f_prime = f.diff(x)
print(f_prime)
f_prime2 = f_prime.diff(x)
print(f_prime2)
dRoots = solveset(f_prime, x)
print(dRoots)
sympy.plotting.plot(f_prime)
# Out:
# 2.66666666666667*(x - 4)**(-0.333333333333333)
# -0.888888888888889*(x - 4)**(-1.33333333333333)
# EmptySet

# %%
# 5
import sympy

x = sympy.Symbol('x')
f = 1.5*x + 85750*x**(-1) + 24500
f_prime = f.diff(x)
dRoots = solveset(f_prime, x)
print(dRoots)

y_fun = lambdify(x,f)
y_vals = [y_fun(r) for r in dRoots]
print(y_vals)
# Out:
# FiniteSet(-239.095517872391, 239.095517872391)
# [23782.7134463828, 25217.2865536172]

# %%
# 14
from sympy import Symbol, lambdify, solve, plotting, oo

t = Symbol('t')
S = 7*t**2 - 21*t + 230

S_prime = S.diff(t)

print("Sales Plot")
plotting.plot(S, xlim=(0, 15), ylim=(0, 1000))


dRoots = solveset(S_prime, t, Interval(0, oo)) # Find the roots of our derivitive where x is between 0 and infinity
print(f"Extreme values are {dRoots}") # gives a set with a single extrema, this is our answer

S_func = lambdify(t, S)  # Turn the symbolic equation into a callable function so we can find the S(t) for our found t value
min_val = S_func(dRoots.args[0])
print(f"Minimum cost is {min_val * 1000} and occurs at {dRoots.args[0]}")
(3/2)*1000
# Out:
# Sales Plot
# Extreme values are FiniteSet(3/2)
# Minimum cost is 214250 and occurs at 3/2
# 1500.0

# %%
from sympy import Symbol, lambdify, solve, plotting, oo, solveset, Interval

t = Symbol('t')
S = (t**2+16) / (4*t)

S_prime = S.diff(t) 

dRoots = solveset(S_prime, t, Interval(1, 12)) 
print(f"Extreme values are {dRoots}") # gives a set with a single extrema, this is our answer

S_func = lambdify(t, S)  # Turn the symbolic equation into a callable function so we can find the S(t) for our found t value
min_val = S_func(dRoots.args[0])
print(f"Minimum is {min_val} and occurs at {dRoots.args[0]}")
# Out:
# Extreme values are FiniteSet(4)
# Minimum is 2.00000000000000 and occurs at 4

# %% [markdown]
# ####
